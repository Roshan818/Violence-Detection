#   inflating: data/no77_xvid.avi
#   inflating: data/no78_xvid.avi
#   inflating: data/no79_xvid.avi
#   inflating: data/no7_xvid.avi
#   inflating: data/no80_xvid.avi
#   inflating: data/no81_xvid.avi
#   inflating: data/no82_xvid.avi
#   inflating: data/no83_xvid.avi
#   inflating: data/no84_xvid.avi
#   inflating: data/no85_xvid.avi
#   inflating: data/no86_xvid.avi
#   inflating: data/no87_xvid.avi
#   inflating: data/no88_xvid.avi
#   inflating: data/no89_xvid.avi
#   inflating: data/no8_xvid.avi
#   inflating: data/no90_xvid.avi
#   inflating: data/no91_xvid.avi
#   inflating: data/no92_xvid.avi
#   inflating: data/no93_xvid.avi
#   inflating: data/no94_xvid.avi
#   inflating: data/no95_xvid.avi
#   inflating: data/no96_xvid.avi
#   inflating: data/no97_xvid.avi
#   inflating: data/no98_xvid.avi
#   inflating: data/no99_xvid.avi
#   inflating: data/no9_xvid.avi

# %%
# %matplotlib inline
import cv2
import os
import numpy as np
import keras
import matplotlib.pyplot as plt
# import download
from random import shuffle
from tensorflow.keras.applications import VGG16
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Activation
import sys
import h5py

# %%
keras.__version__
# Out:
# '2.8.0'

# %%
def print_progress(count, max_count):
    # Percentage completion.
    pct_complete = count / max_count

    # Status-message. Note the \r which means the line should
    # overwrite itself.
    msg = "\r- Progress: {0:.1%}".format(pct_complete)

    # Print it.
    sys.stdout.write(msg)
    sys.stdout.flush()

# %%
in_dir = "/content/gdrive/MyDrive/Violence Detection/data"

# %%
# Frame size  
img_size = 224

img_size_touple = (img_size, img_size)

# Number of channels (RGB)
num_channels = 3

# Flat frame size
img_size_flat = img_size * img_size * num_channels

# Number of classes for classification (Violence-No Violence)
num_classes = 2

# Number of files to train
_num_files_train = 1

# Number of frames per video
_images_per_file = 20

# Number of frames per training set
_num_images_train = _num_files_train * _images_per_file

# Video extension
video_exts = ".avi"

# %%
def get_frames(current_dir, file_name):
    
    in_file = os.path.join(current_dir, file_name)
    
    images = []
    
    vidcap = cv2.VideoCapture(in_file)
    
    success,image = vidcap.read()
        
    count = 0

    while count<_images_per_file:
                
        RGB_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
        res = cv2.resize(RGB_img, dsize=(img_size, img_size),
                                 interpolation=cv2.INTER_CUBIC)
    
        images.append(res)
    
        success,image = vidcap.read()
    
        count += 1
        
    resul = np.array(images)
    
    resul = (resul / 255.).astype(np.float16)
        
    return resul

# %%
def label_video_names(in_dir):
    
    # list containing video names
    names = []
    # list containin video labels [1, 0] if it has violence and [0, 1] if not
    labels = []
    
    
    for current_dir, dir_names,file_names in os.walk(in_dir):
        
        for file_name in file_names:
            
            if file_name[0:2] == 'fi':
                labels.append([1,0])
                names.append(file_name)
            elif file_name[0:2] == 'no':
                labels.append([0,1])
                names.append(file_name)
                     
            
    c = list(zip(names,labels))
    # Suffle the data (names and labels)
    shuffle(c)
    
    names, labels = zip(*c)
            
    return names, labels

# %%
# First get the names and labels of the whole videos
names, labels = label_video_names(in_dir)

# %%
names[12]
# Out:
# 'no146_xvid.avi'

# %%
frames = get_frames(in_dir, names[12])

# %%
visible_frame = (frames*255).astype('uint8')

# %%
plt.imshow(visible_frame[3])

# %%
plt.imshow(visible_frame[17])

# %%
image_model = VGG16(include_top = True, weights = 'imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 11s 0us/step
# 553476096/553467096 [==============================] - 11s 0us/step

# %%
image_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
transfer_layer = image_model.get_layer('fc2')

image_model_transfer = Model(inputs=image_model.input,
                             outputs=transfer_layer.output)

transfer_values_size = K.int_shape(transfer_layer.output)[1]


print("The input of the VGG16 net have dimensions:",K.int_shape(image_model.input)[1:3])

print("The output of the selecter layer of VGG16 net have dimensions: ", transfer_values_size)
# Out:
# The input of the VGG16 net have dimensions: (224, 224)
# The output of the selecter layer of VGG16 net have dimensions:  4096

# %%
def get_transfer_values(current_dir, file_name):
    
    # Pre-allocate input-batch-array for images.
    shape = (_images_per_file,) + img_size_touple + (3,)
    
    image_batch = np.zeros(shape=shape, dtype=np.float16)
    
    image_batch = get_frames(current_dir, file_name)
      
    # Pre-allocate output-array for transfer-values.
    # Note that we use 16-bit floating-points to save memory.
    shape = (_images_per_file, transfer_values_size)
    transfer_values = np.zeros(shape=shape, dtype=np.float16)

    transfer_values = \
            image_model_transfer.predict(image_batch)
            
    return transfer_values

# %%
def proces_transfer(vid_names, in_dir, labels):
    
    count = 0
    
    tam = len(vid_names)
    
    # Pre-allocate input-batch-array for images.
    shape = (_images_per_file,) + img_size_touple + (3,)
    
    while count<tam:
        
        video_name = vid_names[count]
        
        image_batch = np.zeros(shape=shape, dtype=np.float16)
    
        image_batch = get_frames(in_dir, video_name)
        
         # Note that we use 16-bit floating-points to save memory.
        shape = (_images_per_file, transfer_values_size)
        transfer_values = np.zeros(shape=shape, dtype=np.float16)
        
        transfer_values = \
            image_model_transfer.predict(image_batch)
         
        labels1 = labels[count]
        
        aux = np.ones([20,2])
        
        labelss = labels1*aux
        
        yield transfer_values, labelss
        
        count+=1

# %%
def make_files(n_files):
    
    gen = proces_transfer(names_training, in_dir, labels_training)

    numer = 1

    # Read the first chunk to get the column dtypes
    chunk = next(gen)

    row_count = chunk[0].shape[0]
    row_count2 = chunk[1].shape[0]
    
    with h5py.File('prueba.h5', 'w') as f:
    
        # Initialize a resizable dataset to hold the output
        maxshape = (None,) + chunk[0].shape[1:]
        maxshape2 = (None,) + chunk[1].shape[1:]
    
    
        dset = f.create_dataset('data', shape=chunk[0].shape, maxshape=maxshape,
                                chunks=chunk[0].shape, dtype=chunk[0].dtype)
    
        dset2 = f.create_dataset('labels', shape=chunk[1].shape, maxshape=maxshape2,
                                 chunks=chunk[1].shape, dtype=chunk[1].dtype)
    
         # Write the first chunk of rows
        dset[:] = chunk[0]
        dset2[:] = chunk[1]

        for chunk in gen:
            
            if numer == n_files:
            
                break

            # Resize the dataset to accommodate the next chunk of rows
            dset.resize(row_count + chunk[0].shape[0], axis=0)
            dset2.resize(row_count2 + chunk[1].shape[0], axis=0)

            # Write the next chunk
            dset[row_count:] = chunk[0]
            dset2[row_count:] = chunk[1]

            # Increment the row count
            row_count += chunk[0].shape[0]
            row_count2 += chunk[1].shape[0]
            
            print_progress(numer, n_files)
        
            numer += 1

# %%
def make_files_test(n_files):
    
    gen = proces_transfer(names_test, in_dir, labels_test)

    numer = 1

    # Read the first chunk to get the column dtypes
    chunk = next(gen)

    row_count = chunk[0].shape[0]
    row_count2 = chunk[1].shape[0]
    
    with h5py.File('pruebavalidation.h5', 'w') as f:
    
        # Initialize a resizable dataset to hold the output
        maxshape = (None,) + chunk[0].shape[1:]
        maxshape2 = (None,) + chunk[1].shape[1:]
    
    
        dset = f.create_dataset('data', shape=chunk[0].shape, maxshape=maxshape,
                                chunks=chunk[0].shape, dtype=chunk[0].dtype)
    
        dset2 = f.create_dataset('labels', shape=chunk[1].shape, maxshape=maxshape2,
                                 chunks=chunk[1].shape, dtype=chunk[1].dtype)
    
         # Write the first chunk of rows
        dset[:] = chunk[0]
        dset2[:] = chunk[1]

        for chunk in gen:
            
            if numer == n_files:
            
                break

            # Resize the dataset to accommodate the next chunk of rows
            dset.resize(row_count + chunk[0].shape[0], axis=0)
            dset2.resize(row_count2 + chunk[1].shape[0], axis=0)

            # Write the next chunk
            dset[row_count:] = chunk[0]
            dset2[row_count:] = chunk[1]

            # Increment the row count
            row_count += chunk[0].shape[0]
            row_count2 += chunk[1].shape[0]
            
            print_progress(numer, n_files)
        
            numer += 1

# %%
training_set = int(len(names)*0.8)
test_set = int(len(names)*0.2)

names_training = names[0:training_set]
names_test = names[training_set:]

labels_training = labels[0:training_set]
labels_test = labels[training_set:]

# %%
make_files(training_set)
# Out:
# - Progress: 99.9%

# %%
def process_alldata_training():
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File('prueba.h5', 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target

# %%
def process_alldata_test():
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File('pruebavalidation.h5', 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target
data, target = process_alldata_training()
data_test, target_test = process_alldata_test()

# %%
chunk_size = 4096
n_chunks = 20
rnn_size = 512

model = Sequential()
model.add(LSTM(rnn_size, input_shape=(n_chunks, chunk_size)))
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dense(50))
model.add(Activation('sigmoid'))
model.add(Dense(2))
model.add(Activation('softmax'))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])

# %%
epoch = 2000
batchS = 500

history = model.fit(np.array(data[0:720]), np.array(target[0:720]), epochs=epoch,
                    validation_data=(np.array(data[720:]), np.array(target[720:])), 
                    batch_size=batchS, verbose=2)
# Out:
# Epoch 1/2000
# 2/2 - 1s - loss: 0.0469 - accuracy: 0.9500 - val_loss: 0.0380 - val_accuracy: 0.9625 - 578ms/epoch - 289ms/step
# Epoch 2/2000
# 2/2 - 0s - loss: 0.0458 - accuracy: 0.9514 - val_loss: 0.0387 - val_accuracy: 0.9500 - 324ms/epoch - 162ms/step
# Epoch 3/2000
# 2/2 - 0s - loss: 0.0455 - accuracy: 0.9514 - val_loss: 0.0521 - val_accuracy: 0.9250 - 314ms/epoch - 157ms/step
# Epoch 4/2000
# 2/2 - 0s - loss: 0.0460 - accuracy: 0.9486 - val_loss: 0.0405 - val_accuracy: 0.9500 - 316ms/epoch - 158ms/step
# Epoch 5/2000
# 2/2 - 0s - loss: 0.0509 - accuracy: 0.9403 - val_loss: 0.0381 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 6/2000
# 2/2 - 0s - loss: 0.0482 - accuracy: 0.9486 - val_loss: 0.0429 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 7/2000
# 2/2 - 0s - loss: 0.0447 - accuracy: 0.9514 - val_loss: 0.0493 - val_accuracy: 0.9375 - 317ms/epoch - 158ms/step
# Epoch 8/2000
# 2/2 - 0s - loss: 0.0535 - accuracy: 0.9333 - val_loss: 0.0598 - val_accuracy: 0.9250 - 316ms/epoch - 158ms/step
# Epoch 9/2000
# 2/2 - 0s - loss: 0.0537 - accuracy: 0.9319 - val_loss: 0.0399 - val_accuracy: 0.9500 - 318ms/epoch - 159ms/step
# Epoch 10/2000
# 2/2 - 0s - loss: 0.0491 - accuracy: 0.9458 - val_loss: 0.0417 - val_accuracy: 0.9500 - 321ms/epoch - 161ms/step
# Epoch 11/2000
# 2/2 - 0s - loss: 0.0453 - accuracy: 0.9514 - val_loss: 0.0762 - val_accuracy: 0.9000 - 318ms/epoch - 159ms/step
# Epoch 12/2000
# 2/2 - 0s - loss: 0.0654 - accuracy: 0.9208 - val_loss: 0.0417 - val_accuracy: 0.9500 - 316ms/epoch - 158ms/step
# Epoch 13/2000
# 2/2 - 0s - loss: 0.0501 - accuracy: 0.9431 - val_loss: 0.0379 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 14/2000
# 2/2 - 0s - loss: 0.0449 - accuracy: 0.9514 - val_loss: 0.0626 - val_accuracy: 0.9250 - 318ms/epoch - 159ms/step
# Epoch 15/2000
# 2/2 - 0s - loss: 0.0517 - accuracy: 0.9361 - val_loss: 0.0498 - val_accuracy: 0.9375 - 311ms/epoch - 156ms/step
# Epoch 16/2000
# 2/2 - 0s - loss: 0.0553 - accuracy: 0.9319 - val_loss: 0.0371 - val_accuracy: 0.9625 - 312ms/epoch - 156ms/step
# Epoch 17/2000
# 2/2 - 0s - loss: 0.0432 - accuracy: 0.9514 - val_loss: 0.0509 - val_accuracy: 0.9250 - 318ms/epoch - 159ms/step
# Epoch 18/2000
# 2/2 - 0s - loss: 0.0470 - accuracy: 0.9486 - val_loss: 0.0436 - val_accuracy: 0.9375 - 318ms/epoch - 159ms/step
# Epoch 19/2000
# 2/2 - 0s - loss: 0.0494 - accuracy: 0.9458 - val_loss: 0.0377 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 20/2000
# 2/2 - 0s - loss: 0.0434 - accuracy: 0.9542 - val_loss: 0.0630 - val_accuracy: 0.9250 - 318ms/epoch - 159ms/step
# Epoch 21/2000
# 2/2 - 0s - loss: 0.0526 - accuracy: 0.9347 - val_loss: 0.0433 - val_accuracy: 0.9375 - 263ms/epoch - 132ms/step
# Epoch 22/2000
# 2/2 - 0s - loss: 0.0483 - accuracy: 0.9472 - val_loss: 0.0370 - val_accuracy: 0.9625 - 323ms/epoch - 161ms/step
# Epoch 23/2000
# 2/2 - 0s - loss: 0.0417 - accuracy: 0.9569 - val_loss: 0.0529 - val_accuracy: 0.9250 - 323ms/epoch - 161ms/step
# Epoch 24/2000
# 2/2 - 0s - loss: 0.0463 - accuracy: 0.9542 - val_loss: 0.0386 - val_accuracy: 0.9500 - 319ms/epoch - 159ms/step
# Epoch 25/2000
# 2/2 - 0s - loss: 0.0439 - accuracy: 0.9542 - val_loss: 0.0383 - val_accuracy: 0.9625 - 337ms/epoch - 169ms/step
# Epoch 26/2000
# 2/2 - 0s - loss: 0.0402 - accuracy: 0.9583 - val_loss: 0.0481 - val_accuracy: 0.9375 - 324ms/epoch - 162ms/step
# Epoch 27/2000
# 2/2 - 0s - loss: 0.0460 - accuracy: 0.9500 - val_loss: 0.0381 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 28/2000
# 2/2 - 0s - loss: 0.0475 - accuracy: 0.9472 - val_loss: 0.0367 - val_accuracy: 0.9625 - 325ms/epoch - 162ms/step
# Epoch 29/2000
# 2/2 - 0s - loss: 0.0446 - accuracy: 0.9500 - val_loss: 0.0403 - val_accuracy: 0.9625 - 313ms/epoch - 156ms/step
# Epoch 30/2000
# 2/2 - 0s - loss: 0.0424 - accuracy: 0.9542 - val_loss: 0.0482 - val_accuracy: 0.9250 - 356ms/epoch - 178ms/step
# Epoch 31/2000
# 2/2 - 0s - loss: 0.0548 - accuracy: 0.9347 - val_loss: 0.0391 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 32/2000
# 2/2 - 0s - loss: 0.0420 - accuracy: 0.9569 - val_loss: 0.0373 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 33/2000
# 2/2 - 0s - loss: 0.0398 - accuracy: 0.9583 - val_loss: 0.0398 - val_accuracy: 0.9500 - 317ms/epoch - 159ms/step
# Epoch 34/2000
# 2/2 - 0s - loss: 0.0431 - accuracy: 0.9542 - val_loss: 0.0373 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 35/2000
# 2/2 - 0s - loss: 0.0443 - accuracy: 0.9514 - val_loss: 0.0366 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 36/2000
# 2/2 - 0s - loss: 0.0467 - accuracy: 0.9486 - val_loss: 0.0365 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 37/2000
# 2/2 - 0s - loss: 0.0439 - accuracy: 0.9514 - val_loss: 0.0366 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 38/2000
# 2/2 - 0s - loss: 0.0417 - accuracy: 0.9569 - val_loss: 0.0485 - val_accuracy: 0.9375 - 319ms/epoch - 159ms/step
# Epoch 39/2000
# 2/2 - 0s - loss: 0.0521 - accuracy: 0.9361 - val_loss: 0.0517 - val_accuracy: 0.9250 - 319ms/epoch - 160ms/step
# Epoch 40/2000
# 2/2 - 0s - loss: 0.0470 - accuracy: 0.9514 - val_loss: 0.0368 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 41/2000
# 2/2 - 0s - loss: 0.0436 - accuracy: 0.9556 - val_loss: 0.0415 - val_accuracy: 0.9500 - 320ms/epoch - 160ms/step
# Epoch 42/2000
# 2/2 - 0s - loss: 0.0443 - accuracy: 0.9514 - val_loss: 0.0603 - val_accuracy: 0.9250 - 317ms/epoch - 158ms/step
# Epoch 43/2000
# 2/2 - 0s - loss: 0.0494 - accuracy: 0.9458 - val_loss: 0.0378 - val_accuracy: 0.9625 - 326ms/epoch - 163ms/step
# Epoch 44/2000
# 2/2 - 0s - loss: 0.0429 - accuracy: 0.9528 - val_loss: 0.0400 - val_accuracy: 0.9500 - 316ms/epoch - 158ms/step
# Epoch 45/2000
# 2/2 - 0s - loss: 0.0431 - accuracy: 0.9556 - val_loss: 0.0456 - val_accuracy: 0.9500 - 328ms/epoch - 164ms/step
# Epoch 46/2000
# 2/2 - 0s - loss: 0.0435 - accuracy: 0.9542 - val_loss: 0.0363 - val_accuracy: 0.9625 - 325ms/epoch - 163ms/step
# Epoch 47/2000
# 2/2 - 0s - loss: 0.0397 - accuracy: 0.9556 - val_loss: 0.0366 - val_accuracy: 0.9625 - 323ms/epoch - 162ms/step
# Epoch 48/2000
# 2/2 - 0s - loss: 0.0394 - accuracy: 0.9597 - val_loss: 0.0402 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 49/2000
# 2/2 - 0s - loss: 0.0410 - accuracy: 0.9583 - val_loss: 0.0363 - val_accuracy: 0.9625 - 334ms/epoch - 167ms/step
# Epoch 50/2000
# 2/2 - 0s - loss: 0.0392 - accuracy: 0.9597 - val_loss: 0.0390 - val_accuracy: 0.9500 - 316ms/epoch - 158ms/step
# Epoch 51/2000
# 2/2 - 0s - loss: 0.0416 - accuracy: 0.9569 - val_loss: 0.0379 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 52/2000
# 2/2 - 0s - loss: 0.0399 - accuracy: 0.9583 - val_loss: 0.0379 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 53/2000
# 2/2 - 0s - loss: 0.0387 - accuracy: 0.9611 - val_loss: 0.0374 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 54/2000
# 2/2 - 0s - loss: 0.0403 - accuracy: 0.9556 - val_loss: 0.0361 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 55/2000
# 2/2 - 0s - loss: 0.0380 - accuracy: 0.9611 - val_loss: 0.0368 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 56/2000
# 2/2 - 0s - loss: 0.0387 - accuracy: 0.9597 - val_loss: 0.0362 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 57/2000
# 2/2 - 0s - loss: 0.0379 - accuracy: 0.9611 - val_loss: 0.0361 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 58/2000
# 2/2 - 0s - loss: 0.0377 - accuracy: 0.9611 - val_loss: 0.0362 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 59/2000
# 2/2 - 0s - loss: 0.0377 - accuracy: 0.9611 - val_loss: 0.0361 - val_accuracy: 0.9625 - 333ms/epoch - 167ms/step
# Epoch 60/2000
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9611 - val_loss: 0.0362 - val_accuracy: 0.9625 - 325ms/epoch - 163ms/step
# Epoch 61/2000
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 62/2000
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9611 - val_loss: 0.0364 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 63/2000
# 2/2 - 0s - loss: 0.0375 - accuracy: 0.9611 - val_loss: 0.0362 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 64/2000
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 65/2000
# 2/2 - 0s - loss: 0.0372 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 66/2000
# 2/2 - 0s - loss: 0.0372 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 67/2000
# 2/2 - 0s - loss: 0.0370 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 306ms/epoch - 153ms/step
# Epoch 68/2000
# 2/2 - 0s - loss: 0.0370 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 69/2000
# 2/2 - 0s - loss: 0.0369 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 323ms/epoch - 162ms/step
# Epoch 70/2000
# 2/2 - 0s - loss: 0.0369 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 334ms/epoch - 167ms/step
# Epoch 71/2000
# 2/2 - 0s - loss: 0.0368 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 72/2000
# 2/2 - 0s - loss: 0.0368 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 73/2000
# 2/2 - 0s - loss: 0.0368 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 325ms/epoch - 163ms/step
# Epoch 74/2000
# 2/2 - 0s - loss: 0.0368 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 75/2000
# 2/2 - 0s - loss: 0.0368 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 326ms/epoch - 163ms/step
# Epoch 76/2000
# 2/2 - 0s - loss: 0.0368 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 77/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 329ms/epoch - 165ms/step
# Epoch 78/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 79/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 80/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 334ms/epoch - 167ms/step
# Epoch 81/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 326ms/epoch - 163ms/step
# Epoch 82/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 83/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 84/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 85/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 86/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 323ms/epoch - 161ms/step
# Epoch 87/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 88/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 89/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 90/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 91/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 92/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 93/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 94/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 95/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 96/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 331ms/epoch - 166ms/step
# Epoch 97/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 98/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 99/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 100/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 101/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 326ms/epoch - 163ms/step
# Epoch 102/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 325ms/epoch - 162ms/step
# Epoch 103/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 104/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 105/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 106/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 323ms/epoch - 162ms/step
# Epoch 107/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 108/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 355ms/epoch - 177ms/step
# Epoch 109/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 110/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 111/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 333ms/epoch - 166ms/step
# Epoch 112/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 113/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 114/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 115/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 116/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 117/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 118/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 119/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 120/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 121/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 122/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 123/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 356ms/epoch - 178ms/step
# Epoch 124/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 125/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 126/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 334ms/epoch - 167ms/step
# Epoch 127/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 376ms/epoch - 188ms/step
# Epoch 128/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 361ms/epoch - 180ms/step
# Epoch 129/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 130/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 325ms/epoch - 162ms/step
# Epoch 131/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 132/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 358ms/epoch - 179ms/step
# Epoch 133/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 134/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 135/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 136/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 137/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 138/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 139/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 140/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 141/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 142/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 143/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 325ms/epoch - 163ms/step
# Epoch 144/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 145/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 146/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 355ms/epoch - 178ms/step
# Epoch 147/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 148/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 358ms/epoch - 179ms/step
# Epoch 149/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 150/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 151/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 325ms/epoch - 163ms/step
# Epoch 152/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 153/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 154/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 155/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 353ms/epoch - 176ms/step
# Epoch 156/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 157/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 158/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 159/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 160/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 357ms/epoch - 178ms/step
# Epoch 161/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 162/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 163/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 164/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 165/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 166/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 167/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 306ms/epoch - 153ms/step
# Epoch 168/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 169/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 328ms/epoch - 164ms/step
# Epoch 170/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 312ms/epoch - 156ms/step
# Epoch 171/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 172/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 173/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 325ms/epoch - 162ms/step
# Epoch 174/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 175/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 176/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 177/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 353ms/epoch - 176ms/step
# Epoch 178/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 179/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 180/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 181/2000
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 182/2000
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 183/2000
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 308ms/epoch - 154ms/step
# Epoch 184/2000
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 312ms/epoch - 156ms/step
# Epoch 185/2000
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 301ms/epoch - 150ms/step
# Epoch 186/2000
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 312ms/epoch - 156ms/step
# Epoch 187/2000
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 313ms/epoch - 156ms/step
# Epoch 188/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 189/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 190/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 191/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 192/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 193/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 194/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 313ms/epoch - 157ms/step
# Epoch 195/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 313ms/epoch - 156ms/step
# Epoch 196/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 197/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 198/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 199/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 200/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 201/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 202/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 310ms/epoch - 155ms/step
# Epoch 203/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 311ms/epoch - 155ms/step
# Epoch 204/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 205/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 206/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 207/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 323ms/epoch - 162ms/step
# Epoch 208/2000
# 2/2 - 0s - loss: 0.0353 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 309ms/epoch - 154ms/step
# Epoch 209/2000
# 2/2 - 0s - loss: 0.0353 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 210/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 211/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 212/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 213/2000
# 2/2 - 0s - loss: 0.0351 - accuracy: 0.9625 - val_loss: 0.0355 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 214/2000
# 2/2 - 0s - loss: 0.0349 - accuracy: 0.9625 - val_loss: 0.0354 - val_accuracy: 0.9625 - 304ms/epoch - 152ms/step
# Epoch 215/2000
# 2/2 - 0s - loss: 0.0348 - accuracy: 0.9625 - val_loss: 0.0353 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 216/2000
# 2/2 - 0s - loss: 0.0347 - accuracy: 0.9625 - val_loss: 0.0350 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 217/2000
# 2/2 - 0s - loss: 0.0347 - accuracy: 0.9625 - val_loss: 0.0348 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 218/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0353 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 219/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 220/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 310ms/epoch - 155ms/step
# Epoch 221/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 222/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 223/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 224/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 309ms/epoch - 155ms/step
# Epoch 225/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 310ms/epoch - 155ms/step
# Epoch 226/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 227/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 228/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 309ms/epoch - 154ms/step
# Epoch 229/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0366 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 230/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 231/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 232/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 233/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 307ms/epoch - 153ms/step
# Epoch 234/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 235/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 236/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 326ms/epoch - 163ms/step
# Epoch 237/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 312ms/epoch - 156ms/step
# Epoch 238/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 239/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 240/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 241/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 242/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 243/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 244/2000
# 2/2 - 0s - loss: 0.0353 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 245/2000
# 2/2 - 0s - loss: 0.0353 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 352ms/epoch - 176ms/step
# Epoch 246/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 310ms/epoch - 155ms/step
# Epoch 247/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 248/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 249/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0356 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 250/2000
# 2/2 - 0s - loss: 0.0351 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 251/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 252/2000
# 2/2 - 0s - loss: 0.0351 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 253/2000
# 2/2 - 0s - loss: 0.0350 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 254/2000
# 2/2 - 0s - loss: 0.0350 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 255/2000
# 2/2 - 0s - loss: 0.0348 - accuracy: 0.9625 - val_loss: 0.0353 - val_accuracy: 0.9625 - 307ms/epoch - 154ms/step
# Epoch 256/2000
# 2/2 - 0s - loss: 0.0349 - accuracy: 0.9625 - val_loss: 0.0353 - val_accuracy: 0.9625 - 313ms/epoch - 157ms/step
# Epoch 257/2000
# 2/2 - 0s - loss: 0.0349 - accuracy: 0.9625 - val_loss: 0.0356 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 258/2000
# 2/2 - 0s - loss: 0.0348 - accuracy: 0.9625 - val_loss: 0.0354 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 259/2000
# 2/2 - 0s - loss: 0.0347 - accuracy: 0.9625 - val_loss: 0.0350 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 260/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9625 - val_loss: 0.0355 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 261/2000
# 2/2 - 0s - loss: 0.0347 - accuracy: 0.9625 - val_loss: 0.0348 - val_accuracy: 0.9625 - 335ms/epoch - 168ms/step
# Epoch 262/2000
# 2/2 - 0s - loss: 0.0348 - accuracy: 0.9625 - val_loss: 0.0348 - val_accuracy: 0.9625 - 313ms/epoch - 156ms/step
# Epoch 263/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 349ms/epoch - 174ms/step
# Epoch 264/2000
# 2/2 - 0s - loss: 0.0347 - accuracy: 0.9625 - val_loss: 0.0347 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 265/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9625 - val_loss: 0.0342 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 266/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9625 - val_loss: 0.0340 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 267/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9625 - val_loss: 0.0338 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 268/2000
# 2/2 - 0s - loss: 0.0342 - accuracy: 0.9625 - val_loss: 0.0340 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 269/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9625 - val_loss: 0.0345 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 270/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9625 - val_loss: 0.0334 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 271/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9625 - val_loss: 0.0336 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 272/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9625 - val_loss: 0.0330 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 273/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9625 - val_loss: 0.0342 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 274/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 275/2000
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 276/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 277/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0362 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 278/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 279/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0366 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 280/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 281/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 282/2000
# 2/2 - 0s - loss: 0.0367 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 283/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 334ms/epoch - 167ms/step
# Epoch 284/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 285/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9625 - val_loss: 0.0363 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 286/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 287/2000
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 313ms/epoch - 157ms/step
# Epoch 288/2000
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 289/2000
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 290/2000
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 291/2000
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 292/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 325ms/epoch - 163ms/step
# Epoch 293/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 294/2000
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 350ms/epoch - 175ms/step
# Epoch 295/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 323ms/epoch - 162ms/step
# Epoch 296/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 297/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 298/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0356 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 299/2000
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 300/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 301/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0360 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 302/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 303/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 304/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 305/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 306/2000
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 307/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 308/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 338ms/epoch - 169ms/step
# Epoch 309/2000
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9625 - val_loss: 0.0361 - val_accuracy: 0.9625 - 360ms/epoch - 180ms/step
# Epoch 310/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0358 - val_accuracy: 0.9625 - 325ms/epoch - 163ms/step
# Epoch 311/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 332ms/epoch - 166ms/step
# Epoch 312/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0356 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 313/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 314/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 315/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 316/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 317/2000
# 2/2 - 0s - loss: 0.0353 - accuracy: 0.9625 - val_loss: 0.0356 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 318/2000
# 2/2 - 0s - loss: 0.0353 - accuracy: 0.9625 - val_loss: 0.0356 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 319/2000
# 2/2 - 0s - loss: 0.0353 - accuracy: 0.9625 - val_loss: 0.0356 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 320/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0359 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 321/2000
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9625 - val_loss: 0.0357 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 322/2000
# 2/2 - 0s - loss: 0.0351 - accuracy: 0.9625 - val_loss: 0.0355 - val_accuracy: 0.9625 - 354ms/epoch - 177ms/step
# Epoch 323/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0354 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 324/2000
# 2/2 - 0s - loss: 0.0351 - accuracy: 0.9625 - val_loss: 0.0352 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 325/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9625 - val_loss: 0.0353 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 326/2000
# 2/2 - 0s - loss: 0.0349 - accuracy: 0.9625 - val_loss: 0.0356 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 327/2000
# 2/2 - 0s - loss: 0.0351 - accuracy: 0.9625 - val_loss: 0.0351 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 328/2000
# 2/2 - 0s - loss: 0.0347 - accuracy: 0.9625 - val_loss: 0.0352 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 329/2000
# 2/2 - 0s - loss: 0.0348 - accuracy: 0.9625 - val_loss: 0.0349 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 330/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9625 - val_loss: 0.0353 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 331/2000
# 2/2 - 0s - loss: 0.0350 - accuracy: 0.9625 - val_loss: 0.0348 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 332/2000
# 2/2 - 0s - loss: 0.0342 - accuracy: 0.9625 - val_loss: 0.0378 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 333/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9625 - val_loss: 0.0432 - val_accuracy: 0.9500 - 319ms/epoch - 159ms/step
# Epoch 334/2000
# 2/2 - 0s - loss: 0.0432 - accuracy: 0.9444 - val_loss: 0.1466 - val_accuracy: 0.8375 - 319ms/epoch - 160ms/step
# Epoch 335/2000
# 2/2 - 0s - loss: 0.1525 - accuracy: 0.8292 - val_loss: 0.1667 - val_accuracy: 0.8125 - 318ms/epoch - 159ms/step
# Epoch 336/2000
# 2/2 - 0s - loss: 0.1606 - accuracy: 0.8125 - val_loss: 0.0896 - val_accuracy: 0.8875 - 317ms/epoch - 159ms/step
# Epoch 337/2000
# 2/2 - 0s - loss: 0.0687 - accuracy: 0.9181 - val_loss: 0.0628 - val_accuracy: 0.9250 - 322ms/epoch - 161ms/step
# Epoch 338/2000
# 2/2 - 0s - loss: 0.0633 - accuracy: 0.9181 - val_loss: 0.0828 - val_accuracy: 0.8875 - 314ms/epoch - 157ms/step
# Epoch 339/2000
# 2/2 - 0s - loss: 0.0676 - accuracy: 0.9194 - val_loss: 0.0470 - val_accuracy: 0.9375 - 315ms/epoch - 157ms/step
# Epoch 340/2000
# 2/2 - 0s - loss: 0.0587 - accuracy: 0.9292 - val_loss: 0.0381 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 341/2000
# 2/2 - 0s - loss: 0.0497 - accuracy: 0.9444 - val_loss: 0.0386 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 342/2000
# 2/2 - 0s - loss: 0.0481 - accuracy: 0.9444 - val_loss: 0.0416 - val_accuracy: 0.9500 - 319ms/epoch - 160ms/step
# Epoch 343/2000
# 2/2 - 0s - loss: 0.0465 - accuracy: 0.9472 - val_loss: 0.0651 - val_accuracy: 0.9250 - 315ms/epoch - 157ms/step
# Epoch 344/2000
# 2/2 - 0s - loss: 0.0567 - accuracy: 0.9278 - val_loss: 0.0410 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 345/2000
# 2/2 - 0s - loss: 0.0500 - accuracy: 0.9431 - val_loss: 0.0361 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 346/2000
# 2/2 - 0s - loss: 0.0420 - accuracy: 0.9542 - val_loss: 0.0500 - val_accuracy: 0.9250 - 319ms/epoch - 160ms/step
# Epoch 347/2000
# 2/2 - 0s - loss: 0.0430 - accuracy: 0.9542 - val_loss: 0.0435 - val_accuracy: 0.9500 - 317ms/epoch - 159ms/step
# Epoch 348/2000
# 2/2 - 0s - loss: 0.0517 - accuracy: 0.9375 - val_loss: 0.0360 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 349/2000
# 2/2 - 0s - loss: 0.0401 - accuracy: 0.9569 - val_loss: 0.0400 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 350/2000
# 2/2 - 0s - loss: 0.0394 - accuracy: 0.9597 - val_loss: 0.0344 - val_accuracy: 0.9500 - 321ms/epoch - 160ms/step
# Epoch 351/2000
# 2/2 - 0s - loss: 0.0454 - accuracy: 0.9472 - val_loss: 0.0365 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 352/2000
# 2/2 - 0s - loss: 0.0432 - accuracy: 0.9514 - val_loss: 0.0355 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 353/2000
# 2/2 - 0s - loss: 0.0416 - accuracy: 0.9514 - val_loss: 0.0359 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 354/2000
# 2/2 - 0s - loss: 0.0428 - accuracy: 0.9528 - val_loss: 0.0405 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 355/2000
# 2/2 - 0s - loss: 0.0400 - accuracy: 0.9569 - val_loss: 0.0365 - val_accuracy: 0.9500 - 318ms/epoch - 159ms/step
# Epoch 356/2000
# 2/2 - 0s - loss: 0.0444 - accuracy: 0.9486 - val_loss: 0.0364 - val_accuracy: 0.9625 - 354ms/epoch - 177ms/step
# Epoch 357/2000
# 2/2 - 0s - loss: 0.0392 - accuracy: 0.9569 - val_loss: 0.0494 - val_accuracy: 0.9250 - 321ms/epoch - 161ms/step
# Epoch 358/2000
# 2/2 - 0s - loss: 0.0428 - accuracy: 0.9556 - val_loss: 0.0434 - val_accuracy: 0.9375 - 317ms/epoch - 159ms/step
# Epoch 359/2000
# 2/2 - 0s - loss: 0.0458 - accuracy: 0.9458 - val_loss: 0.0464 - val_accuracy: 0.9375 - 356ms/epoch - 178ms/step
# Epoch 360/2000
# 2/2 - 0s - loss: 0.0447 - accuracy: 0.9528 - val_loss: 0.0353 - val_accuracy: 0.9625 - 325ms/epoch - 162ms/step
# Epoch 361/2000
# 2/2 - 0s - loss: 0.0422 - accuracy: 0.9500 - val_loss: 0.0348 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 362/2000
# 2/2 - 0s - loss: 0.0391 - accuracy: 0.9583 - val_loss: 0.0379 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 363/2000
# 2/2 - 0s - loss: 0.0372 - accuracy: 0.9597 - val_loss: 0.0376 - val_accuracy: 0.9500 - 317ms/epoch - 159ms/step
# Epoch 364/2000
# 2/2 - 0s - loss: 0.0383 - accuracy: 0.9569 - val_loss: 0.0397 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 365/2000
# 2/2 - 0s - loss: 0.0430 - accuracy: 0.9514 - val_loss: 0.0381 - val_accuracy: 0.9500 - 316ms/epoch - 158ms/step
# Epoch 366/2000
# 2/2 - 0s - loss: 0.0474 - accuracy: 0.9417 - val_loss: 0.0351 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 367/2000
# 2/2 - 0s - loss: 0.0433 - accuracy: 0.9500 - val_loss: 0.0346 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 368/2000
# 2/2 - 0s - loss: 0.0417 - accuracy: 0.9500 - val_loss: 0.0351 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 369/2000
# 2/2 - 0s - loss: 0.0395 - accuracy: 0.9542 - val_loss: 0.0361 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 370/2000
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9583 - val_loss: 0.0406 - val_accuracy: 0.9500 - 317ms/epoch - 159ms/step
# Epoch 371/2000
# 2/2 - 0s - loss: 0.0396 - accuracy: 0.9569 - val_loss: 0.0464 - val_accuracy: 0.9375 - 337ms/epoch - 168ms/step
# Epoch 372/2000
# 2/2 - 0s - loss: 0.0400 - accuracy: 0.9569 - val_loss: 0.0351 - val_accuracy: 0.9625 - 323ms/epoch - 161ms/step
# Epoch 373/2000
# 2/2 - 0s - loss: 0.0352 - accuracy: 0.9611 - val_loss: 0.0352 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 374/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9625 - val_loss: 0.0364 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 375/2000
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9597 - val_loss: 0.0344 - val_accuracy: 0.9625 - 323ms/epoch - 162ms/step
# Epoch 376/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9611 - val_loss: 0.0345 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 377/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9639 - val_loss: 0.0345 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 378/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9625 - val_loss: 0.0338 - val_accuracy: 0.9625 - 325ms/epoch - 163ms/step
# Epoch 379/2000
# ...
# Epoch 1876/2000
# 2/2 - 0s - loss: 0.0320 - accuracy: 0.9653 - val_loss: 0.0336 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1877/2000
# 2/2 - 0s - loss: 0.0319 - accuracy: 0.9653 - val_loss: 0.0376 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 1878/2000
# 2/2 - 0s - loss: 0.0320 - accuracy: 0.9653 - val_loss: 0.0334 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 1879/2000
# 2/2 - 0s - loss: 0.0314 - accuracy: 0.9653 - val_loss: 0.0331 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 1880/2000
# 2/2 - 0s - loss: 0.0312 - accuracy: 0.9653 - val_loss: 0.0362 - val_accuracy: 0.9625 - 325ms/epoch - 163ms/step
# Epoch 1881/2000
# 2/2 - 0s - loss: 0.0316 - accuracy: 0.9653 - val_loss: 0.0328 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 1882/2000
# 2/2 - 0s - loss: 0.0307 - accuracy: 0.9653 - val_loss: 0.0326 - val_accuracy: 0.9625 - 313ms/epoch - 156ms/step
# Epoch 1883/2000
# 2/2 - 0s - loss: 0.0308 - accuracy: 0.9653 - val_loss: 0.0319 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 1884/2000
# 2/2 - 0s - loss: 0.0310 - accuracy: 0.9653 - val_loss: 0.0321 - val_accuracy: 0.9625 - 313ms/epoch - 157ms/step
# Epoch 1885/2000
# 2/2 - 0s - loss: 0.0306 - accuracy: 0.9653 - val_loss: 0.0332 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 1886/2000
# 2/2 - 0s - loss: 0.0298 - accuracy: 0.9653 - val_loss: 0.0341 - val_accuracy: 0.9500 - 362ms/epoch - 181ms/step
# Epoch 1887/2000
# 2/2 - 0s - loss: 0.0297 - accuracy: 0.9653 - val_loss: 0.0306 - val_accuracy: 0.9625 - 326ms/epoch - 163ms/step
# Epoch 1888/2000
# 2/2 - 0s - loss: 0.0303 - accuracy: 0.9653 - val_loss: 0.0316 - val_accuracy: 0.9625 - 329ms/epoch - 165ms/step
# Epoch 1889/2000
# 2/2 - 0s - loss: 0.0298 - accuracy: 0.9653 - val_loss: 0.0319 - val_accuracy: 0.9625 - 364ms/epoch - 182ms/step
# Epoch 1890/2000
# 2/2 - 0s - loss: 0.0287 - accuracy: 0.9653 - val_loss: 0.0317 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 1891/2000
# 2/2 - 0s - loss: 0.0291 - accuracy: 0.9667 - val_loss: 0.0309 - val_accuracy: 0.9625 - 332ms/epoch - 166ms/step
# Epoch 1892/2000
# 2/2 - 0s - loss: 0.0297 - accuracy: 0.9653 - val_loss: 0.0356 - val_accuracy: 0.9625 - 351ms/epoch - 176ms/step
# Epoch 1893/2000
# 2/2 - 0s - loss: 0.0285 - accuracy: 0.9708 - val_loss: 0.0332 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 1894/2000
# 2/2 - 0s - loss: 0.0271 - accuracy: 0.9694 - val_loss: 0.0342 - val_accuracy: 0.9625 - 330ms/epoch - 165ms/step
# Epoch 1895/2000
# 2/2 - 0s - loss: 0.0303 - accuracy: 0.9694 - val_loss: 0.0290 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 1896/2000
# 2/2 - 0s - loss: 0.0302 - accuracy: 0.9667 - val_loss: 0.0287 - val_accuracy: 0.9750 - 329ms/epoch - 165ms/step
# Epoch 1897/2000
# 2/2 - 0s - loss: 0.0261 - accuracy: 0.9708 - val_loss: 0.0276 - val_accuracy: 0.9750 - 327ms/epoch - 163ms/step
# Epoch 1898/2000
# 2/2 - 0s - loss: 0.0261 - accuracy: 0.9708 - val_loss: 0.0279 - val_accuracy: 0.9750 - 315ms/epoch - 157ms/step
# Epoch 1899/2000
# 2/2 - 0s - loss: 0.0259 - accuracy: 0.9708 - val_loss: 0.0397 - val_accuracy: 0.9500 - 322ms/epoch - 161ms/step
# Epoch 1900/2000
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9611 - val_loss: 0.0319 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 1901/2000
# 2/2 - 0s - loss: 0.0348 - accuracy: 0.9653 - val_loss: 0.0336 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 1902/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9653 - val_loss: 0.0409 - val_accuracy: 0.9500 - 317ms/epoch - 158ms/step
# Epoch 1903/2000
# 2/2 - 0s - loss: 0.0347 - accuracy: 0.9653 - val_loss: 0.0356 - val_accuracy: 0.9625 - 328ms/epoch - 164ms/step
# Epoch 1904/2000
# 2/2 - 0s - loss: 0.0344 - accuracy: 0.9653 - val_loss: 0.0330 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 1905/2000
# 2/2 - 0s - loss: 0.0345 - accuracy: 0.9653 - val_loss: 0.0340 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1906/2000
# 2/2 - 0s - loss: 0.0342 - accuracy: 0.9653 - val_loss: 0.0379 - val_accuracy: 0.9625 - 323ms/epoch - 161ms/step
# Epoch 1907/2000
# 2/2 - 0s - loss: 0.0343 - accuracy: 0.9653 - val_loss: 0.0362 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 1908/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0328 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 1909/2000
# 2/2 - 0s - loss: 0.0343 - accuracy: 0.9653 - val_loss: 0.0318 - val_accuracy: 0.9625 - 326ms/epoch - 163ms/step
# Epoch 1910/2000
# 2/2 - 0s - loss: 0.0343 - accuracy: 0.9653 - val_loss: 0.0341 - val_accuracy: 0.9625 - 325ms/epoch - 162ms/step
# Epoch 1911/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0362 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 1912/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0407 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 1913/2000
# 2/2 - 0s - loss: 0.0342 - accuracy: 0.9653 - val_loss: 0.0403 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 1914/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0364 - val_accuracy: 0.9625 - 347ms/epoch - 173ms/step
# Epoch 1915/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0352 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1916/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0344 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 1917/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0339 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 1918/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0339 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 1919/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0342 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 1920/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0348 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 1921/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0354 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 1922/2000
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9653 - val_loss: 0.0359 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 1923/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0365 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 1924/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0371 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 1925/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0374 - val_accuracy: 0.9625 - 323ms/epoch - 161ms/step
# Epoch 1926/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0373 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 1927/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0369 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 1928/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0365 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1929/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0362 - val_accuracy: 0.9625 - 310ms/epoch - 155ms/step
# Epoch 1930/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0360 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 1931/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 1932/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 1933/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 1934/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 330ms/epoch - 165ms/step
# Epoch 1935/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 1936/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 1937/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0359 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 1938/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0360 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1939/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0360 - val_accuracy: 0.9625 - 360ms/epoch - 180ms/step
# Epoch 1940/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0361 - val_accuracy: 0.9625 - 331ms/epoch - 165ms/step
# Epoch 1941/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0361 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 1942/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0361 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1943/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0361 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 1944/2000
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9653 - val_loss: 0.0361 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 1945/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0360 - val_accuracy: 0.9625 - 350ms/epoch - 175ms/step
# Epoch 1946/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0360 - val_accuracy: 0.9625 - 342ms/epoch - 171ms/step
# Epoch 1947/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0359 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1948/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0359 - val_accuracy: 0.9625 - 313ms/epoch - 157ms/step
# Epoch 1949/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0359 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 1950/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0359 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 1951/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1952/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 1953/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 327ms/epoch - 163ms/step
# Epoch 1954/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1955/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 311ms/epoch - 156ms/step
# Epoch 1956/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 1957/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 312ms/epoch - 156ms/step
# Epoch 1958/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 1959/2000
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 1960/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0358 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 1961/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 1962/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 1963/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 1964/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 1965/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 1966/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 313ms/epoch - 157ms/step
# Epoch 1967/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 1968/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0357 - val_accuracy: 0.9625 - 330ms/epoch - 165ms/step
# Epoch 1969/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0356 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 1970/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0356 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1971/2000
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9653 - val_loss: 0.0355 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 1972/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0354 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1973/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0353 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 1974/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0352 - val_accuracy: 0.9625 - 321ms/epoch - 160ms/step
# Epoch 1975/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0352 - val_accuracy: 0.9625 - 325ms/epoch - 162ms/step
# Epoch 1976/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0352 - val_accuracy: 0.9625 - 319ms/epoch - 160ms/step
# Epoch 1977/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0351 - val_accuracy: 0.9625 - 351ms/epoch - 176ms/step
# Epoch 1978/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0352 - val_accuracy: 0.9625 - 317ms/epoch - 159ms/step
# Epoch 1979/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0352 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 1980/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0353 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 1981/2000
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9653 - val_loss: 0.0353 - val_accuracy: 0.9625 - 311ms/epoch - 156ms/step
# Epoch 1982/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0354 - val_accuracy: 0.9625 - 317ms/epoch - 158ms/step
# Epoch 1983/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0354 - val_accuracy: 0.9625 - 315ms/epoch - 158ms/step
# Epoch 1984/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0354 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1985/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0354 - val_accuracy: 0.9625 - 323ms/epoch - 162ms/step
# Epoch 1986/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0353 - val_accuracy: 0.9625 - 320ms/epoch - 160ms/step
# Epoch 1987/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0353 - val_accuracy: 0.9625 - 319ms/epoch - 159ms/step
# Epoch 1988/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0353 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 1989/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0352 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 1990/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0352 - val_accuracy: 0.9625 - 315ms/epoch - 157ms/step
# Epoch 1991/2000
# 2/2 - 0s - loss: 0.0336 - accuracy: 0.9653 - val_loss: 0.0351 - val_accuracy: 0.9625 - 316ms/epoch - 158ms/step
# Epoch 1992/2000
# 2/2 - 0s - loss: 0.0335 - accuracy: 0.9653 - val_loss: 0.0351 - val_accuracy: 0.9625 - 330ms/epoch - 165ms/step
# Epoch 1993/2000
# 2/2 - 0s - loss: 0.0335 - accuracy: 0.9653 - val_loss: 0.0351 - val_accuracy: 0.9625 - 322ms/epoch - 161ms/step
# Epoch 1994/2000
# 2/2 - 0s - loss: 0.0335 - accuracy: 0.9653 - val_loss: 0.0350 - val_accuracy: 0.9625 - 324ms/epoch - 162ms/step
# Epoch 1995/2000
# 2/2 - 0s - loss: 0.0335 - accuracy: 0.9653 - val_loss: 0.0349 - val_accuracy: 0.9625 - 326ms/epoch - 163ms/step
# Epoch 1996/2000
# 2/2 - 0s - loss: 0.0335 - accuracy: 0.9653 - val_loss: 0.0349 - val_accuracy: 0.9625 - 321ms/epoch - 161ms/step
# Epoch 1997/2000
# 2/2 - 0s - loss: 0.0335 - accuracy: 0.9653 - val_loss: 0.0349 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1998/2000
# 2/2 - 0s - loss: 0.0335 - accuracy: 0.9653 - val_loss: 0.0349 - val_accuracy: 0.9625 - 318ms/epoch - 159ms/step
# Epoch 1999/2000
# 2/2 - 0s - loss: 0.0335 - accuracy: 0.9653 - val_loss: 0.0349 - val_accuracy: 0.9625 - 314ms/epoch - 157ms/step
# Epoch 2000/2000
# 2/2 - 0s - loss: 0.0335 - accuracy: 0.9653 - val_loss: 0.0348 - val_accuracy: 0.9625 - 304ms/epoch - 152ms/step

# %%
result = model.evaluate(np.array(data_test), np.array(target_test))
# Out:
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0418 - accuracy: 0.9550

# %%
for name, value in zip(model.metrics_names, result):
    print(name, value)
# Out:
# loss 0.04183574765920639
# accuracy 0.9549999833106995

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path.eps', format='eps', dpi=1000)
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path1.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
